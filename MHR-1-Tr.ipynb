# %%
#Tr和竖线

import numpy as np
import matplotlib.pyplot as plt

#Tr
x_star=np.linspace(-0.8257418243481833,2.6207413942088964,100)
J0=x**3

Tr1=-3*x_star**2+6*x_star-1
Tr2=-3*x_star**2+8*x_star-1

#竖线
y_line=np.linspace(-1.8,1.8,100)
y_line_1=np.linspace(-5.8,5.8,100)
Line1=np.zeros(100,dtype=float)+0.0061792
Line2=np.zeros(100,dtype=float)+5.9938208
Line3=np.zeros(100,dtype=float)+8
Line4=np.zeros(100,dtype=float)-0.5630317
Line5=np.zeros(100,dtype=float)+4

#绘图
plt.plot(J0,Tr1,'r',label=r'$Tr=-3 J_0^{2/3}+2 \beta J_0^{1/3}-1,\beta=3$')
plt.plot(J0,Tr2,'r,--',label=r'$Tr=-3 J_0^{2/3}+2 \beta J_0^{1/3}-1,\beta=4$')
plt.plot(Line4,y_line,'deepskyblue',label=r'$J_0=-0.5630317$')
plt.plot(Line1,y_line_1,'k',label=r'$J_0=0.0061792$')
plt.plot(Line5,y_line,'m',label=r'$J_0=4$')
plt.plot(Line2,y_line_1,'gray',label=r'$J_0=5.9938208$')
plt.plot(Line3,y_line,'g',label=r'$J_0=8$')
plt.text(-2.5,0.7,r'$\chi$')
plt.text(-0.5,0.7,r'$\delta$')
plt.text(1.9,0.7,r'$\rho$')
plt.text(4.5,0.7,r'$hfo$')
plt.text(6.3,0.7,r'$QPO$')
plt.text(12,0.7,r'$\chi$')
plt.xlabel(r'$J_0$')
plt.ylabel(r'$Trace$')
plt.xlim(-4,18)
plt.ylim(-8,)
plt.legend(loc = 'lower right')
plt.grid()
plt.show()
